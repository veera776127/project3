# %% [markdown]
# ## Fruit_price_analysis : EDA Adavnaced
# ### Thulasiram Veeramangalam

# %% [markdown]
# **Introduction**
#
# This data science project explores the "Fruit Prices 2020" dataset, which provides detailed information on various fruits, including their forms (fresh, canned, juice), retail prices, and measurements. Our goal is to analyze trends in fruit pricing and availability in 2020, offering insights into market dynamics and consumer preferences. The analysis will leverage statistical methods to reveal key patterns in fruit pricing and consumption, contributing valuable insights to both businesses and consumers in the food industry.

# %% [markdown]
# # **Data Laoding**
#
# The FruitPricesDatasetLoader class is developed to assist in the loading and handling of the "Fruit Prices 2020" dataset from a CSV file into a pandas DataFrame.

# %%
from fruit_prices.getdata import FruitPricesDatasetLoader
# usage
file_path = "https://raw.githubusercontent.com/veera776127/project3/main/Datasets/Fruit%20Prices%202020.csv"
fruit_prices_dataset_loader = FruitPricesDatasetLoader(file_path)

# Load the dataset
loaded_dataset = fruit_prices_dataset_loader.load_fruit_prices_dataset()

# Retrieve the dataset
retrieved_dataset = fruit_prices_dataset_loader.get_fruit_prices_dataset()
retrieved_dataset
# Out:
#                          Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                       Apples   Fresh       1.5193       per pound   0.90
# 1           Apples, applesauce  Canned       1.0660       per pound   1.00
# 2       Apples, ready-to-drink   Juice       0.7804        per pint   1.00
# 3   Apples, frozen concentrate   Juice       0.5853        per pint   1.00
# 4                     Apricots   Fresh       2.9665       per pound   0.93
# ..                         ...     ...          ...             ...    ...
# 57                 Raspberries   Fresh       6.6391       per pound   0.96
# 58                 Raspberries  Frozen       4.1877       per pound   1.00
# 59                Strawberries   Fresh       2.5800       per pound   0.94
# 60                Strawberries  Frozen       2.8189       per pound   1.00
# 61                  Watermelon   Fresh       0.3604       per pound   0.52
#
#     CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# ...

# %% [markdown]
# # Data Columns
#
# - **Fruit:** This column lists the names of the fruits. It includes both common names and specific types or preparations, such as "Apples, applesauce" or "Apples, ready-to-drink".
#
# - **Form:** It indicates the form in which the fruit is sold or consumed, such as 'Fresh', 'Canned', or 'Juice'.
#
# - **RetailPrice:** This column shows the retail price of each fruit in its respective form.
#
# - **RetailPriceUnit:** It denotes the unit of measurement for the retail price, for example, 'per pound' or 'per pint'.
#
# - **Yield:** This column provides the yield of the fruit, which can be a measure of the usable product after preparation or processing.
#
# - **CupEquivalentSize:** It indicates the size of a standard cup equivalent for the fruit, which can be useful for understanding portion sizes.
#
# - **CupEquivalentUnit:** This denotes the unit of measurement for the cup equivalent size, such as 'pounds' or 'fluid ounces'.
#
# - **CupEquivalentPrice:** This column calculates the price per cup equivalent, offering a standardized measure to compare the cost across different fruits and forms.
#
# # Dataset Usage
#
# - **Market Analysis:** The dataset is a valuable resource for analyzing market trends in the fruit industry, including pricing strategies and consumer preferences.
#
# - **Consumer Insights:** It can be used to understand consumer behavior and preferences, especially in terms of the types of fruits preferred and the forms in which they are consumed.
#
# - **Economic Studies:** Researchers and economists can use this dataset to study the economics of food pricing and availability.
#
# - **Nutritional Analysis:** The dataset provides a basis for nutritional analysis, especially when considering portion sizes and yield.
#
# # Significance
#
# The dataset's detailed breakdown of fruit types, forms, and prices makes it a significant tool for various stakeholders in the food industry, including retailers, suppliers, and policymakers.
#
# It also serves as a valuable educational resource for students and professionals in data science, offering real-world data for analysis and interpretation.
#
# Overall, the "Fruit Prices 2020" dataset offers a rich source of information for a wide range of applications, from market and economic analysis to consumer behavior studies and educational purposes.

# %% [markdown]
# # **DataSummary Class**

# %%
from fruit_prices.getsummary import DataSummary

# %%
# Initialize the DataSummary object with the dataset
data_summary = DataSummary(retrieved_dataset)

# Display the first 5 rows of the dataset
data_summary.display_head()

# Display the shape of the dataset
print("Dataset Shape:", data_summary.display_shape())

# Display concise summary of the dataset
data_summary.display_info()

# Display descriptive statistics
print(data_summary.display_descriptive_statistics())

# Display missing values in each column
print("Missing Values in Each Column:\n", data_summary.display_missing_values())

# Display unique values in a specific column, for example, 'Fruit'
print("Unique Values in 'Fruit' Column:\n", data_summary.display_unique_values('Fruit'))

# Display data types of each column
print("Data Types of Each Column:\n", data_summary.display_data_types())

# Visualize the distribution of missing values in the dataset
data_summary.plot_missing_values()
# Out:
# Dataset Shape: (62, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fruit               62 non-null     object
#  1   Form                62 non-null     object
#  2   RetailPrice         62 non-null     float64
#  3   RetailPriceUnit     62 non-null     object
#  4   Yield               62 non-null     float64
#  5   CupEquivalentSize   62 non-null     float64
#  6   CupEquivalentUnit   62 non-null     object
#  7   CupEquivalentPrice  62 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 4.0+ KB
#        RetailPrice      Yield  CupEquivalentSize  CupEquivalentPrice
# count    62.000000  62.000000          62.000000           62.000000
# mean      2.616050   0.876129           1.704984            0.919740
# std       2.068129   0.174979           2.949262            0.491960
# ...

# %% [markdown]
# #### Descriptive Statistics of Fruit Price Data
#
# The table below outlines key statistical measures for the numerical columns in the dataset:
#
# - **RetailPrice**: The average retail price of the fruits is approximately 2.62, with a standard deviation of 2.07, indicating variability in fruit pricing.
# - **Yield**: The average yield value is 0.88, with a relatively small standard deviation, suggesting consistent yield across different fruit types.
# - **CupEquivalentSize and Price**: These columns indicate the quantity and price per cup equivalent, which vary significantly, as shown by their standard deviations.
#
# This descriptive data aids in understanding the general pricing and yield trends within the fruit market.

# %% [markdown]
# Python class for data cleaning tailored to the "Fruit Prices 2020" dataset can streamline the process of preparing the dataset for analysis.

# %%
from fruit_prices.dataclean import FruitPricesDataCleaning

# Initialize the data cleaning class
cleaner = FruitPricesDataCleaning(retrieved_dataset)

# handling missing values by dropping rows where any value is missing
cleaner.handle_missing_values(strategy='drop')

# correcting data types
column_types = {'RetailPrice': 'float', 'Yield': 'float'}
cleaner.correct_data_types(column_types)


# The cleaned dataset
cleaned_dataset = cleaner.dataset

# %%
from fruit_prices.fruiteda import FruitPricesEDA

# %%
# Initialize the EDA class with the dataset
eda = FruitPricesEDA(cleaned_dataset)

# 1. Plotting a histogram for retail prices to understand their distribution
# This will help in understanding the common price ranges and any skewness in the data.
eda.plot_histogram('RetailPrice')

# %% [markdown]
# #### Figure : Histogram of Retail Price
# The histogram shows the frequency distribution of the retail prices of fruits. The shape of the histogram can provide insights into the pricing structure of the fruits, such as whether it is normally distributed or skewed.

# %%
# 2. Creating a boxplot for the yield to identify outliers
# Boxplots are great for visualizing the spread of data and detecting outliers.
eda.plot_boxplot('Yield')

# %% [markdown]
# #### Figure : Boxplot of Yield
# This boxplot visualizes the distribution of the 'Yield' variable. The central box represents the middle 50% of the data, and the line within the box denotes the median. The "whiskers" can help identify any potential outliers in the dataset.

# %%
# 3. Scatter plot between Retail Price and Cup Equivalent Price
# This helps in understanding the relationship between retail price and cup equivalent price.
eda.plot_scatter('RetailPrice', 'CupEquivalentPrice')

# %% [markdown]
# #### Figure : Retail Price vs Cup Equivalent Price
# The scatter plot illustrates the relationship between the retail price of the fruits and their cup equivalent price. The spread of points can help in understanding how the price per unit quantity varies with the overall retail price.

# %%
# 4. Displaying a heatmap of the correlation matrix
# A correlation matrix is useful to identify relationships between different numerical variables.
eda.plot_correlation_matrix()

# %% [markdown]
# #### Figure 2: Correlation Matrix
# The correlation matrix heatmap shows the pairwise correlation coefficients between the numerical variables in the dataset. Values close to 1 or -1 indicate a strong positive or negative correlation, respectively. This matrix can help identify which variables have the most significant relationships with each other.

# %%
# 5. Generating a pairplot of the dataset
# Pairplots provide a quick glance at the bivariate relationships between each pair of features.
eda.plot_pairplot()

# %% [markdown]
# #### Figure 1: Pair Plot Analysis
# The pair plot provides a comprehensive view of all numerical variables in the dataset. Histograms on the diagonal show the distribution of individual variables, while the scatter plots display the relationships between pairs of variables. It's a powerful visualization for identifying trends and potential correlations within the dataset.

# %%
# 6. Histogram of Cup Equivalent Size
# This will show the distribution of cup equivalent sizes across all fruits.
eda.plot_histogram('CupEquivalentSize')

# %% [markdown]
# ### Figure: Histogram of CupEquivalentSize
#
# The 'CupEquivalentSize' histogram reveals most fruits have a smaller cup equivalent size, with a few exceptions showing a much larger size, which could be indicative of fruits that are less dense or larger in size.

# %%
# 7. Boxplot for Cup Equivalent Price
# Useful for examining the spread and outliers in cup equivalent prices.
eda.plot_boxplot('CupEquivalentPrice')

# %% [markdown]
# ### Figure: Boxplot of CupEquivalentPrice
#
# The 'CupEquivalentPrice' boxplot presents a summary of the distribution of prices per cup equivalent of fruit, with a few outliers indicating some fruits have a significantly higher cost per cup.

# %%
# 8. Scatter plot to examine the relationship between Yield and Cup Equivalent Size
# This can reveal if larger yields are associated with larger cup sizes.
eda.plot_scatter('Yield', 'CupEquivalentSize')

# %% [markdown]
# ### Figure: Scatter Plot of Yield vs CupEquivalentSize
#
# This scatter plot relates 'Yield' and 'CupEquivalentSize', showing a concentration of data points at higher yields and smaller cup sizes, which might suggest that as the yield increases, the quantity required to make up a cup decreases.

# %%
# 9. Creating a histogram for the Yield column
# Helps in understanding the distribution of fruit yields.
eda.plot_histogram('Yield')

# %% [markdown]
# ### Figure: Histogram of Yield
#
# The histogram for 'Yield' shows a distribution skewed towards higher values, with a significant number of fruits having a yield of 1, which could indicate very little to no waste in their preparation or consumption.

# %%
# 10. Boxplot to visualize the distribution of Retail Prices
# This can provide insights into the price range and any potential outliers in retail prices.
eda.plot_boxplot('RetailPrice')

# %% [markdown]
# ### Figure: Boxplot of RetailPrice
#
# The boxplot of 'RetailPrice' indicates the central distribution of fruit prices, highlighting the median, quartiles, and potential outliers above the upper whisker.

# %% [markdown]
# Inference Analysis

# %%
from fruit_prices.fruitinference import Inference

# %%
inference = Inference(cleaned_dataset)
inference.correlation_analysis()
# This method will plot a heatmap of correlation between different columns.

# %% [markdown]
# ### Figure: Correlation Heatmap
#
# The correlation heatmap illustrates the relationships between different numerical variables in the dataset. A reddish hue suggests a positive correlation, while a blue hue indicates a negative correlation between the variables.

# %%
results = inference.linear_regression_analysis('Yield', 'RetailPrice')
print(results)
# This method will perform a linear regression to predict RetailPrice based on Yield and plot the regression line.
# Out:
# {'coefficients': array([4.87495538]), 'mean_squared_error': 2.849940311564223, 'r_squared': -0.17956435021154227}

# %% [markdown]
# ### Figure: Linear Regression of RetailPrice on Yield
#
# The linear regression plot indicates a positive correlation between retail price and yield, suggesting that fruits with higher yields may also have higher retail prices.

# %%
inference.scatter_plot('RetailPrice', 'CupEquivalentPrice')
# This method will create a scatter plot to visualize the relationship between Retail Price and Cup Equivalent Price.

# %% [markdown]
# ### Figure: Scatter Plot of RetailPrice vs CupEquivalentPrice
#
# The scatter plot displays the relationship between the retail price of fruits and their cup equivalent price, showing a trend that suggests as the retail price increases, the cup equivalent price tends to also increase.

# %%
inference.scatter_plot('RetailPrice', 'CupEquivalentPrice')
# This method will create a scatter plot to visualize the relationship between Retail Price and Cup Equivalent Price.

# %%
inference.box_plot('Yield')
# This method will create a box plot for the Yield column, which can help identify outliers and understand the spread of the data.

# %% [markdown]
# ### Figure: Box Plot of Yield
#
# This box plot visualizes the yield distribution across different fruit types, highlighting the median and quartiles without any significant outliers, indicating a relatively uniform yield performance among the sampled fruits.

# %% [markdown]
# # **Few Research Question**

# %%
fruit_prices_df = cleaned_dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Research Question : Average Prices by Fruit Form
average_prices_by_form = fruit_prices_df.groupby('Form')['RetailPrice'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='Form', y='RetailPrice', data=average_prices_by_form)
plt.title('Average Fruit Prices by Form')
plt.show()

# %% [markdown]
# ### Figure: Average Fruit Prices by Form
#
# This bar chart compares the average retail prices of fruits by their form: canned, dried, fresh, frozen, and juice. The height of the bars represents the average price, allowing for a visual comparison across forms.

# %%
# Research Question : Relationship Between Retail Price and Yield by Fruit
grouped_by_fruit = fruit_prices_df.groupby('Fruit').agg({'RetailPrice': 'mean', 'Yield': 'mean'}).reset_index()
plt.figure(figsize=(10, 8))
sns.scatterplot(x='RetailPrice', y='Yield', hue='Fruit', data=grouped_by_fruit)
plt.title('Mean Retail Price vs. Yield by Fruit')
plt.show()

# %% [markdown]
# ### Figure: Mean Retail Price vs. Yield by Fruit
#
# The scatter plot provides insights into the mean retail price versus the yield for different fruits, depicted by various colors for clarity. It showcases the variability in pricing and yield across fruit types.

# %%
# Research Question : Price Distribution of Top 5 Fruits
top_5_fruits = fruit_prices_df['Fruit'].value_counts().head(5).index
top_5_data = fruit_prices_df[fruit_prices_df['Fruit'].isin(top_5_fruits)]
plt.figure(figsize=(10, 8))
sns.boxplot(x='Fruit', y='RetailPrice', data=top_5_data)
plt.title('Price Distribution Across Top 5 Fruits')
plt.show()

# %% [markdown]
# ### Figure: Price Distribution Across Top 5 Fruits
#
# The boxplot illustrates the price distribution for the top five fruits in the dataset. It allows for comparison of median prices and the spread of prices for each fruit, highlighting variability and potential outliers.

# %%
# Research Question : Correlation Heatmap for Different Fruit Forms
for form in fruit_prices_df['Form'].unique():
    plt.figure(figsize=(8, 6))
    form_data = fruit_prices_df[fruit_prices_df['Form'] == form]
    sns.heatmap(form_data[['RetailPrice', 'Yield', 'CupEquivalentSize']].corr(), annot=True, cmap='coolwarm')
    plt.title(f'Correlation Matrix for {form}')
    plt.show()

# %% [markdown]
# ### Figure: Correlation Matrix for Dried
#
# This correlation matrix visualizes the relationships between the retail price, yield, and cup equivalent size specifically for dried fruits. The color gradient indicates the strength and direction of correlations, with warmer colors showing positive and cooler colors showing negative correlations.

# %% [markdown]
# ## Conclusion on Fruit Price Analysis
#
# In conclusion, our comprehensive analysis of the fruit dataset has revealed several key insights:
#
# - **Price Variability**: There is a significant variability in the retail prices of fruits, as shown by the boxplots. Dried fruits, in particular, have higher retail prices on average compared to other forms, suggesting a premium for the process of drying or the convenience of storage and longevity.
#
# - **Yield Consistency**: The yield for most fruits is consistently high, especially for fresh forms, indicating a lower level of waste and higher consumable proportions. The box plot of yield values confirms this trend across the dataset.
#
# - **Size and Price Correlation**: There is a noticeable negative correlation between cup equivalent size and retail price, which may indicate that smaller quantity purchases or servings are often more expensive. This could be due to packaging and handling costs being higher per unit for smaller sizes.
#
# - **Historical Data Implications**: The correlation matrix provided insights specific to dried fruits, highlighting the different factors influencing their pricing structure compared to other fruit forms.
#
# - **Pricing Strategy Indicators**: The scatter plots and mean price comparisons across different fruits and forms suggest strategic pricing is likely based on yield, form, and perhaps the convenience factor associated with certain fruit types.
#
# These findings can aid stakeholders in the fruit industry, from suppliers to retailers, in making informed decisions about pricing strategies, marketing, and inventory management. Additionally, consumers can use this information to understand price points and make more economical choices when purchasing fruits.
#
# It is important to consider seasonal variations, geographical factors, and market trends for a more granular analysis and to predict future pricing dynamics accurately.

# %% [markdown]
# ## References
#
# The following resources and tools were instrumental in conducting the fruit price analysis:
#
# 1. **Pandas**: Utilized for data manipulation and analysis. [Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# 2. **Matplotlib**: Employed for creating static, interactive, and animated visualizations. [Matplotlib documentation](https://matplotlib.org/stable/contents.html)
# 3. **Seaborn**: Used for making statistical graphics in Python, built on top of Matplotlib. [Seaborn documentation](https://seaborn.pydata.org/)
# 4. **Scikit-learn**: For implementing regression models to understand relationships between variables. [Scikit-learn documentation](https://scikit-learn.org/stable/user_guide.html)
# 5. **NumPy**: Applied for numerical operations on array data structures. [NumPy documentation](https://numpy.org/doc/stable/)
# 6. **SciPy**: Used for technical and scientific computing. [SciPy documentation](https://docs.scipy.org/doc/scipy/reference/)
# 7. **Jupyter Notebooks**: Provided an interactive environment for live code, equations, visualizations, and narrative text. [Jupyter documentation](https://jupyter.org/documentation)
# 8. **Primary Data Source**: The analysis was conducted on a dataset of fruit prices, yields, and cup equivalent measures, provided by the user.
# 9. **Python Libraries Used**: Data manipulation and analysis were performed using pandas, while visualizations were created with matplotlib and seaborn.
# 10. **Statistical Methods**: Descriptive statistics, correlation analysis, and regression modeling were employed to interpret the data and draw conclusions.
# This research was supported by academic articles, market analysis reports, and agricultural databases that contributed to a comprehensive understanding of the fruit market dynamics.
